# %% [markdown]
# # BLS public API
#
# In this notebook we will:
# 1. Obtain an API key from the BLS
# 2. Add the key to APIkeys.py (or APIkeys.R)
# 3. Find which data sets and surveys are available on the BLS's API server
# 4. Learn how to construct an API GET request
#
# **Note:** This part 1

# %% [markdown]
# ## Obtaining an API key
#
# To get your API key you need to register.  Please click [here](https://www.bls.gov/developers/). In the second paragraph there is a [link](https://data.bls.gov/registrationEngine/) to register for an API key. Click and fill in the details.
#
# You will get an e-mail containing your API key as well a link to follow to validate your key.
#
# The key should be 32 characters long.

# %% [markdown]
# ## Adding the key to environment variables
#
# Open your APIkeys.py (or APIkeys.R) file in a text editor (not in Jupyter!).
#
# Add the following line:
#
# ```Python
# os.environ["BLS_API_key"] = "***************************"
# ```
# or
#
# ```R
# Sys.setenv(BLS_API_key = '**************************')
# ```
#
# Replace the astrics with your API key. Save and close.

# %% [markdown]
# **Run the script:**
#
# ```Python
# %run APIkeys.py
# ```
# or
# ```R
# source('APIkeys.R')
# ```

# %%
source('APIkeys.R')

# %% [markdown]
# You can check that the new key is uploaded correctly.
#
# ```R
# a = Sys.getenv('BLS_API_key')
# print(a)
# ```

# %%
# If you want to run this cell, remove the # sign from in the following lines:
#a = Sys.getenv('BLS_API_key')
#print(a)

# %% [markdown]
# ## BLS API documentation
#
# We are ready to use the BLS API server!
#
# The cocumentation for the API is in this [link](https://www.bls.gov/developers/api_signature_v2.htm) and it includes code examples.
#
# First, let's load ```httr``` and ```jsonlite``` packages.

# %%
library(httr)
library(jsonlite)

# %% [markdown]
# ### List of all surveys
#
# We start by looking at all the surveys that the BLS has and that you can access.
#
# You can follow this [link](https://api.bls.gov/publicAPI/v2/surveys) to see a list of surveys in a JSON format.
#
# Let's collect it into a variable.

# %%
surveys_url = "https://api.bls.gov/publicAPI/v2/surveys"
s = GET(surveys_url)
s_json = fromJSON(content(s,"text",encoding = "UTF-8"))

# %%
s_json
# Out:
# $status
# [1] "REQUEST_SUCCEEDED"
#
# $responseTime
# [1] 45
#
# $message
# list()
#
# $Results
# $Results$survey
#    survey_abbreviation
# 1                   AP
# 2                   BD
# 3                   BG
# 4                   BP
# 5                   CC
# 6                   CD
# 7                   CE
# 8                   CF
# 9                   CH
# 10                  CI
# 11                  CM
# 12                  CS
# 13                  CU
# 14                  CW
# 15                  CX
# 16                  EB
# 17                  EC
# 18                  EE
# 19                  EI
# 20                  EN
# 21                  EP
# 22                  EW
# 23                  FI
# 24                  FM
# 25                  FW
# 26                  GG
# 27                  GP
# 28                  HC
# 29                  HS
# 30                  II
# 31                  IN
# 32                  IP
# 33                  IS
# 34                  JL
# 35                  JT
# 36                  LA
# 37                  LE
# 38                  LF
# 39                  LI
# 40                  LN
# 41                  LU
# 42                  ML
# 43                  MP
# 44                  MU
# 45                  MW
# 46                  NB
# 47                  NC
# 48                  ND
# 49                  NW
# 50                  OE
# 51                  OR
# 52                  PC
# 53                  PD
# 54                  PF
# 55                  PI
# 56                  PR
# 57                  SA
# 58                  SH
# 59                  SI
# 60                  SM
# 61                  SU
# 62                  TU
# 63                  WD
# 64                  WM
# 65                  WP
# 66                  WS
#                                                                                 survey_name
# 1                                                 Consumer Price Index - Average Price Data
# 2                                                              Business Employment Dynamics
# 3                               Collective Bargaining Agreements-State and Local Government
# 4                                           Collective Bargaining Agreements-Private Sector
# 5                                                  Employer Costs for Employee Compensation
# 6                    Nonfatal cases involving days away from work: selected characteristics
# 7  Employment, Hours, and Earnings from the Current Employment Statistics survey (National)
# 8                                                     Census of Fatal Occupational Injuries
# 9      Nonfatal cases involving days away from work: selected characteristics (2003 - 2010)
# 10                                                                    Employment Cost Index
# 11                                                 Employer Costs for Employee Compensation
# 12    Nonfatal cases involving days away from work: selected characteristics (2011 forward)
# 13                                               Consumer Price Index - All Urban Consumers
# 14                           Consumer Price Index - Urban Wage Earners and Clerical Workers
# 15                                                              Consumer Expenditure Survey
# 16                                                                 Employee Benefits Survey
# 17                                                                    Employment Cost Index
# 18                                                 National Employment, Hours, and Earnings
# 19                                                              Import/Export Price Indexes
# 20                                                 Quarterly Census of Employment and Wages
# 21                                                       Employment Projections by Industry
# 22                                           Quarterly Census of Employment and Wages (SIC)
# 23                                      Census of Fatal Occupational Injuries (2003 - 2010)
# 24             Marital and family labor force statistics from the Current Population Survey
# 25                                     Census of Fatal Occupational Injuries (2011 forward)
# 26                                                                 Green Goods and Services
# 27                                                                       Geographic Profile
# 28            Nonfatal cases involving days away from work: Selected Characteristics (2002)
# 29                            Occupational injuries and illnesses: industry data (pre-1989)
# 30                                       Occupational injuries and illnesses: industry data
# 31                                                           International Labor Comparison
# 32                                                                    Industry Productivity
# 33                                        Occupational injuries and illnesses industry data
# 34                                                   Job Openings and Labor Turnover Survey
# 35                                                   Job Openings and Labor Turnover Survey
# 36                                                       Local Area Unemployment Statistics
# 37                       Weekly and hourly earnings data from the Current Population Survey
# 38                          Labor Force Statistics from the Current Population Survey (SIC)
# 39                            Consumer Price Index - Department Store Inventory Price Index
# 40                                Labor Force Statistics from the Current Population Survey
# 41                                Union affiliation data from the Current Population Survey
# 42                                                                   Mass Layoff Statistics
# 43                                                    Major Sector Multifactor Productivity
# 44                                  Consumer Price Index - All Urban Consumers (Old Series)
# 45              Consumer Price Index - Urban Wage Earners and Clerical Workers (Old Series)
# 46                                                    National Compensation Survey-Benefits
# 47                                                             National Compensation Survey
# 48                                                       Producer Price Index Industry Data
# 49                                                             National Compensation Survey
# 50                                                       Occupational Employment Statistics
# 51                                                                Occupational Requirements
# 52                                                       Producer Price Index Industry Data
# 53                                                Producer Price Index - Discontinued (SIC)
# 54                                                    Federal Government Productivity Index
# 55                                                              Industry Productivity Index
# 56                                                      Major Sector Productivity and Costs
# 57                                     State and Area Employment, Hours, and Earnings (SIC)
# 58                           Occupational injuries and illnesses: industry data (1989-2001)
# 59                                Occupational injuries and illnesses: industry data (2002)
# 60                                           State and Area Employment, Hours, and Earnings
# 61                                      Consumer Price Index - Chained Consumer Price Index
# 62                                                                        American Time Use
# 63                                       Producer Price Index Commodity-Discontinued Series
# 64                                                                            Wage Modeling
# 65                                                         Producer Price Index-Commodities
# 66                                                                       Work Stoppage Data

# %%
surveys = s_json$Results$survey

# %%
# A list of all the surveys
surveys
# Out:
#    survey_abbreviation
# 1  AP
# 2  BD
# 3  BG
# 4  BP
# 5  CC
# 6  CD
# 7  CE
# 8  CF
# 9  CH
# 10 CI
# 11 CM
# 12 CS
# 13 CU
# 14 CW
# 15 CX
# 16 EB
# 17 EC
# 18 EE
# 19 EI
# 20 EN
# 21 EP
# 22 EW
# 23 FI
# 24 FM
# 25 FW
# 26 GG
# 27 GP
# 28 HC
# 29 HS
# 30 II
# ⋮  ⋮
# 37 LE
# 38 LF
# 39 LI
# 40 LN
# 41 LU
# 42 ML
# 43 MP
# 44 MU
# 45 MW
# 46 NB
# 47 NC
# 48 ND
# 49 NW
# 50 OE
# 51 OR
# 52 PC
# 53 PD
# 54 PF
# 55 PI
# 56 PR
# 57 SA
# 58 SH
# 59 SI
# 60 SM
# 61 SU
# 62 TU
# 63 WD
# 64 WM
# 65 WP
# 66 WS
#    survey_name
# 1  Consumer Price Index - Average Price Data
# 2  Business Employment Dynamics
# 3  Collective Bargaining Agreements-State and Local Government
# 4  Collective Bargaining Agreements-Private Sector
# 5  Employer Costs for Employee Compensation
# 6  Nonfatal cases involving days away from work: selected characteristics
# 7  Employment, Hours, and Earnings from the Current Employment Statistics survey (National)
# 8  Census of Fatal Occupational Injuries
# 9  Nonfatal cases involving days away from work: selected characteristics (2003 - 2010)
# 10 Employment Cost Index
# 11 Employer Costs for Employee Compensation
# 12 Nonfatal cases involving days away from work: selected characteristics (2011 forward)
# 13 Consumer Price Index - All Urban Consumers
# 14 Consumer Price Index - Urban Wage Earners and Clerical Workers
# 15 Consumer Expenditure Survey
# 16 Employee Benefits Survey
# 17 Employment Cost Index
# 18 National Employment, Hours, and Earnings
# 19 Import/Export Price Indexes
# 20 Quarterly Census of Employment and Wages
# 21 Employment Projections by Industry
# 22 Quarterly Census of Employment and Wages (SIC)
# 23 Census of Fatal Occupational Injuries (2003 - 2010)
# 24 Marital and family labor force statistics from the Current Population Survey
# 25 Census of Fatal Occupational Injuries (2011 forward)
# 26 Green Goods and Services
# 27 Geographic Profile
# 28 Nonfatal cases involving days away from work: Selected Characteristics (2002)
# 29 Occupational injuries and illnesses: industry data (pre-1989)
# 30 Occupational injuries and illnesses: industry data
# ⋮  ⋮
# 37 Weekly and hourly earnings data from the Current Population Survey
# 38 Labor Force Statistics from the Current Population Survey (SIC)
# 39 Consumer Price Index - Department Store Inventory Price Index
# 40 Labor Force Statistics from the Current Population Survey
# 41 Union affiliation data from the Current Population Survey
# 42 Mass Layoff Statistics
# 43 Major Sector Multifactor Productivity
# 44 Consumer Price Index - All Urban Consumers (Old Series)
# 45 Consumer Price Index - Urban Wage Earners and Clerical Workers (Old Series)
# 46 National Compensation Survey-Benefits
# 47 National Compensation Survey
# 48 Producer Price Index Industry Data
# 49 National Compensation Survey
# 50 Occupational Employment Statistics
# 51 Occupational Requirements
# 52 Producer Price Index Industry Data
# 53 Producer Price Index - Discontinued (SIC)
# 54 Federal Government Productivity Index
# 55 Industry Productivity Index
# 56 Major Sector Productivity and Costs
# 57 State and Area Employment, Hours, and Earnings (SIC)
# 58 Occupational injuries and illnesses: industry data (1989-2001)
# 59 Occupational injuries and illnesses: industry data (2002)
# 60 State and Area Employment, Hours, and Earnings
# 61 Consumer Price Index - Chained Consumer Price Index
# 62 American Time Use
# 63 Producer Price Index Commodity-Discontinued Series
# 64 Wage Modeling
# 65 Producer Price Index-Commodities
# 66 Work Stoppage Data

# %%
typeof(surveys)
# Out:
# [1] "list"

# %%
# Example 1:
surveys[15,] #the 15th element of the list
# Out:
#    survey_abbreviation survey_name
# 15 CX                  Consumer Expenditure Survey

# %%
#Example 2:
surveys[13,] #CPI for urband consumers
# Out:
#    survey_abbreviation survey_name
# 13 CU                  Consumer Price Index - All Urban Consumers

# %%
for(row in 1:nrow(surveys))
    {
    r = surveys[row,]
    print(paste0(r$survey_name," (" , r$survey_abbreviation , ")" ))
}
# Out:
# [1] "Consumer Price Index - Average Price Data (AP)"
# [1] "Business Employment Dynamics (BD)"
# [1] "Collective Bargaining Agreements-State and Local Government (BG)"
# [1] "Collective Bargaining Agreements-Private Sector (BP)"
# [1] "Employer Costs for Employee Compensation (CC)"
# [1] "Nonfatal cases involving days away from work: selected characteristics (CD)"
# [1] "Employment, Hours, and Earnings from the Current Employment Statistics survey (National) (CE)"
# [1] "Census of Fatal Occupational Injuries (CF)"
# [1] "Nonfatal cases involving days away from work: selected characteristics (2003 - 2010) (CH)"
# [1] "Employment Cost Index (CI)"
# [1] "Employer Costs for Employee Compensation (CM)"
# [1] "Nonfatal cases involving days away from work: selected characteristics (2011 forward) (CS)"
# [1] "Consumer Price Index - All Urban Consumers (CU)"
# [1] "Consumer Price Index - Urban Wage Earners and Clerical Workers (CW)"
# [1] "Consumer Expenditure Survey (CX)"
# [1] "Employee Benefits Survey (EB)"
# [1] "Employment Cost Index (EC)"
# [1] "National Employment, Hours, and Earnings (EE)"
# [1] "Import/Export Price Indexes (EI)"
# [1] "Quarterly Census of Employment and Wages (EN)"
# [1] "Employment Projections by Industry (EP)"
# [1] "Quarterly Census of Employment and Wages (SIC) (EW)"
# [1] "Census of Fatal Occupational Injuries (2003 - 2010) (FI)"
# [1] "Marital and family labor force statistics from the Current Population Survey (FM)"
# [1] "Census of Fatal Occupational Injuries (2011 forward) (FW)"
# [1] "Green Goods and Services (GG)"
# [1] "Geographic Profile (GP)"
# [1] "Nonfatal cases involving days away from work: Selected Characteristics (2002) (HC)"
# [1] "Occupational injuries and illnesses: industry data (pre-1989) (HS)"
# [1] "Occupational injuries and illnesses: industry data (II)"
# [1] "International Labor Comparison (IN)"
# [1] "Industry Productivity (IP)"
# [1] "Occupational injuries and illnesses industry data (IS)"
# [1] "Job Openings and Labor Turnover Survey (JL)"
# [1] "Job Openings and Labor Turnover Survey (JT)"
# [1] "Local Area Unemployment Statistics (LA)"
# [1] "Weekly and hourly earnings data from the Current Population Survey (LE)"
# [1] "Labor Force Statistics from the Current Population Survey (SIC) (LF)"
# [1] "Consumer Price Index - Department Store Inventory Price Index (LI)"
# [1] "Labor Force Statistics from the Current Population Survey (LN)"
# [1] "Union affiliation data from the Current Population Survey (LU)"
# [1] "Mass Layoff Statistics (ML)"
# [1] "Major Sector Multifactor Productivity (MP)"
# [1] "Consumer Price Index - All Urban Consumers (Old Series) (MU)"
# [1] "Consumer Price Index - Urban Wage Earners and Clerical Workers (Old Series) (MW)"
# [1] "National Compensation Survey-Benefits (NB)"
# [1] "National Compensation Survey (NC)"
# [1] "Producer Price Index Industry Data (ND)"
# [1] "National Compensation Survey (NW)"
# [1] "Occupational Employment Statistics (OE)"
# [1] "Occupational Requirements (OR)"
# [1] "Producer Price Index Industry Data (PC)"
# [1] "Producer Price Index - Discontinued (SIC) (PD)"
# [1] "Federal Government Productivity Index (PF)"
# [1] "Industry Productivity Index (PI)"
# [1] "Major Sector Productivity and Costs (PR)"
# [1] "State and Area Employment, Hours, and Earnings (SIC) (SA)"
# [1] "Occupational injuries and illnesses: industry data (1989-2001) (SH)"
# [1] "Occupational injuries and illnesses: industry data (2002) (SI)"
# [1] "State and Area Employment, Hours, and Earnings (SM)"
# [1] "Consumer Price Index - Chained Consumer Price Index (SU)"
# [1] "American Time Use (TU)"
# [1] "Producer Price Index Commodity-Discontinued Series (WD)"
# [1] "Wage Modeling (WM)"
# [1] "Producer Price Index-Commodities (WP)"
# [1] "Work Stoppage Data (WS)"

# %%
l = nrow(surveys) #number of surveys
print(paste("Number of surveys:",l))
# The difference between paste() and paste0() is that the paste() function add a space in between elements by default, while paste0() doesn't. 
# paste(element1, element2, sep = "") is the same as paste0(element1, element2)
# Out:
# [1] "Number of surveys: 66"

# %% [markdown]
# ### Aside:  parenthesis, brackets, etc.
#
# **parenthesis** ```( )``` are used for:
# - changing the order of operations in a mathemtical expression: ```z = 2 * (x + y)```
# - invoking a function call ```cos(1.25)```
# - defining tuples ``` t = (1,2,3)```
#
# **Square brackets** ```[]``` are used for:
# - accessing an element in a list (aka an array) ```surveys[15,]``` is the 15th row of the list ```surveys```, and ```surveys[,1]``` is the 1st column of the list ```surveys```.
#
# **Dollar signs** ```$``` are used for:
# - accessing a key in a named list ```s$survey_name```
#
# **Curly brackets** ```{}``` are used for
# - denoting a block of code in a function / loop

# %% [markdown]
# We can look at a single survey:

# %%
# In R we can chain operations

cu = fromJSON(content(GET("https://api.bls.gov/publicAPI/v2/surveys/CU"),"text",encoding = "UTF-8"))

# %%
cu
# Out:
# $status
# [1] "REQUEST_SUCCEEDED"
#
# $responseTime
# [1] 42
#
# $message
# list()
#
# $Results
# $Results$survey
#                                  survey_name survey_abbreviation
# 1 Consumer Price Index - All Urban Consumers                  CU
#   allowsNetChange allowsPercentChange hasAnnualAverages
# 1           false                true              true

# %% [markdown]
# ## Series ID and format
#
# The full explanation of how to constuct the series (variable) name is [here](https://www.bls.gov/help/hlpforma.htm).
#
# We will go over it in great details for the [CPI data](https://www.bls.gov/help/hlpforma.htm#CX) (survey id CU).
#
# Each variable has a name of length up to 16 characters that has a very specific structure:

# %% [markdown]
# ```
#                       1         2
# 	             12345678901234567890
# 	Series ID    CUUR0000SA0L1E
# 	Positions       Value           Field Name
# 	1-2             CU              Prefix
# 	3               U               Not Seasonal Adjustment Code
# 	4               R               Periodicity Code
# 	5-8             0000            Area Code
# 	9               S               Base Code
# 	10-16           A0L1E           Item Code
# ```
#
# Note:  ```CUUR0000SA0L1E``` is just an example.

# %% [markdown]
# ### First two letters
#
# Since we are going to use the CU survey, every variable name will start with the letters ```CU```.

# %% [markdown]
# ### Third letter
#
# It will always be ```U``` standing for not seasonaly adjusted.
#
# > Indicates the adjustment of time series data to eliminate the effect of intrayear variations which tend to occur during the same period on an annual basis (i.e. Where U=Unadjusted and S=Seasonally Adjusted).

# %% [markdown]
# ### Forth letter
#
# R=monthly and S=semi-annual data. We will use ```R```.
#
# <p style="background-color:#ccccee;font-size: 18px;">
# Therefore, so far, ALL the variables names for the variables that we will aceess will start with ```CUUR```.
#     </p>

# %% [markdown]
# ### DIgits/characters 5-8
#
# These include the area codes used by the BLS (they have nothing to do with phone area codes).
#
# [List of area codes](https://download.bls.gov/pub/time.series/cu/cu.area)
#
# For example:
# - 0000	U.S. city average
# - A104	Pittsburgh, PA
# - A210	Cleveland-Akron, OH
# - S12A	New York-Newark-Jersey City, NY-NJ-PA
# - S49A	Los Angeles-Long Beach-Anaheim, CA
#
# etc...

# %% [markdown]
# # Character 9
#
# Indicates the 'base' of the series, i.e. which time period is normalized to 100.
#
# >Indicates the designated reference date from which price change is measured, where the "current" base year is 1982-84=100 or more recent (S) and the "alternate" base year (A) is prior to the current base year.
#
# We will use ```S```.

# %% [markdown]
# ## Characters 10-16
#
# This part contains upto 7 characters indicatin item code.
#
# [List of item codes](https://download.bls.gov/pub/time.series/cu/cu.item)
#
# <p style="font-size: 24px;color:red;">
#     Warning: The above webpage lists Character 9 AND characters 10-16!
# </p>
#
#
# Examples (characters 10-16):
#
# - A0	All items (That's the CPI that is being published)
# - AF111	Cereals and bakery products
# - ARC	Recreation commodities
# - EFN02	Frozen noncarbonated juices and drinks
#
# etc...
#
# The length of the item code indicates if it's a category, sub-category. sub-sub-category, etc.

# %% [markdown]
# ## Examples:
#
# **Example 1:**  CUURA104SEGD03
#
# <p style="font-size: 32px;-webkit-text-stroke: 2px black;letter-spacing: 10px;">
#     CU|U|R|A104|S|EGD03
# </p>
#
# price index for urban consumers (CU), which is not seasonally adjusted (U), at a monthly frequency (R), for consumers living in the Pittsburgh (A104), using 1982-1984 as the base (S), for laundry and dry cleaning services (SEGD03).
#
# **Example 2:**  CUUR0350SEFK
# <p style="font-size: 32px;-webkit-text-stroke: 2px black;letter-spacing: 10px;">
#     CU|U|R|0350|S|EFK
# </p>
#
# price index for urban consumers (CU), which is not seasonally adjusted (U), at a monthly frequency (R), for consumers living in the South East region (0350), using 1982-1984 as the base (S), for fresh fruits (SEFK).

# %% [markdown]
# ### challange
#
# Can you build the variable name for the price indext for urban consumers living in Dallas-Fort Worth-Arlington, TX, which is not seasonally adjusted, uses 1982-84 as the base for Lettuce?

# %% [markdown]
# # Retrieving data from the API

# %% [markdown]
# ## Single series with no parameters
#
# If you want to retrieve a single series without any aditional parameters (i.e. starting period and end period), you can use a simple GET request without using  your api key!
#
# The following is an example
#
# Taking ```CUURA104SEGD03``` as an example, we would like to get this series of price indices from the BLS.

# %%
base_url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'

series = 'CUUR0000SA0L1E'

url = paste0(base_url, series) #use paste0() here because we don't want extra space in url 

r = fromJSON(content(GET(url),"text",encoding = "UTF-8"))

# %%
r
# Out:
# $status
# [1] "REQUEST_SUCCEEDED"
#
# $responseTime
# [1] 698
#
# $message
# list()
#
# $Results
# $Results$series
#         seriesID
# 1 CUUR0000SA0L1E
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   data
# 1 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, M12, M11, M10, M09, M08, M07, M06, M05, M04, M03, M02, M01, M12, M11, M10, M09, M08, M07, M06, M05, M04, M03, M02, M01, M12, M11, M10, M09, M08, M07, M06, M05, M04, M03, M02, M01, December, November, October, September, August, July, June, May, April, March, February, January, December, November, October, September, August, July, June, May, April, March, February, January, December, November, October, September, August, July, June, May, April, March, February, January, 283.908, 282.754, 281.617, 279.884, 279.507, 279.146, 278.218, 275.893, 273.968, 271.713, 270.696, 269.755, 269.226, 269.473, 269.328, 269.054, 268.756, 267.703, 266.302, 265.799, 266.089, 267.312, 267.268, 266.004, 264.935, 265.108, 265.059, 264.522, 264.169, 263.566, 263.177, 262.590, 262.332, 261.836, 261.114, 260.122

# %%
r$Results$series$data
# Out:
# [[1]]
#    year period periodName   value footnotes
# 1  2021    M12   December 283.908      NULL
# 2  2021    M11   November 282.754      NULL
# 3  2021    M10    October 281.617      NULL
# 4  2021    M09  September 279.884      NULL
# 5  2021    M08     August 279.507      NULL
# 6  2021    M07       July 279.146      NULL
# 7  2021    M06       June 278.218      NULL
# 8  2021    M05        May 275.893      NULL
# 9  2021    M04      April 273.968      NULL
# 10 2021    M03      March 271.713      NULL
# 11 2021    M02   February 270.696      NULL
# 12 2021    M01    January 269.755      NULL
# 13 2020    M12   December 269.226      NULL
# 14 2020    M11   November 269.473      NULL
# 15 2020    M10    October 269.328      NULL
# 16 2020    M09  September 269.054      NULL
# 17 2020    M08     August 268.756      NULL
# 18 2020    M07       July 267.703      NULL
# 19 2020    M06       June 266.302      NULL
# 20 2020    M05        May 265.799      NULL
# 21 2020    M04      April 266.089      NULL
# 22 2020    M03      March 267.312      NULL
# 23 2020    M02   February 267.268      NULL
# 24 2020    M01    January 266.004      NULL
# 25 2019    M12   December 264.935      NULL
# 26 2019    M11   November 265.108      NULL
# 27 2019    M10    October 265.059      NULL
# 28 2019    M09  September 264.522      NULL
# 29 2019    M08     August 264.169      NULL
# 30 2019    M07       July 263.566      NULL
# 31 2019    M06       June 263.177      NULL
# 32 2019    M05        May 262.590      NULL
# 33 2019    M04      April 262.332      NULL
# 34 2019    M03      March 261.836      NULL
# 35 2019    M02   February 261.114      NULL
# 36 2019    M01    January 260.122      NULL

# %% [markdown]
# **Be careful!** the number of requests you can make like that is limited.
#
# ```JSON
# {'status': 'REQUEST_NOT_PROCESSED',
#  'responseTime': 0,
#  'message': ['Request could not be serviced, as the daily threshold for total number of requests allocated to the user has been reached.'],
#  'Results': {}}
#  ```
